# %% [markdown]
# <a href="https://colab.research.google.com/github/seongcho1/mnetest/blob/main/mne_my_1_preproc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# L8: MNE tutorial Part #1 - Load and Segment continuous EEG data
#
# https://www.youtube.com/watch?v=IYuAPisoUeI

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %%
# !pip install mne
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 54.8 MB/s eta 0:00:00
# ...

# %%
#from google.colab import drive
#drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
#%matplotlib notebook
# %matplotlib inline

import mne
import matplotlib.pyplot as plt
# Out:
# Channels marked as bad:
# none
# Channels marked as bad:
# none

# %%
#https://github.com/jona-sassenhagen/mne_workshop_amsterdam/blob/master/oddball_example_small-fif.gz
#fname = "oddball_example_small-fif.gz"
# !git clone https://github.com/jona-sassenhagen/mne_workshop_amsterdam
# Out:
# fatal: destination path 'mne_workshop_amsterdam' already exists and is not an empty directory.

# %%
fname = "mne_workshop_amsterdam/oddball_example_small-fif.gz"
#fname = "oddball_example_samll-fif.gz"
print(fname)
# Out:
# mne_workshop_amsterdam/oddball_example_small-fif.gz

# %%
raw = mne.io.read_raw_fif(fname)
# Out:
# Opening raw data file mne_workshop_amsterdam/oddball_example_small-fif.gz...
# <ipython-input-61-78767f98f250>:1: RuntimeWarning: This filename (mne_workshop_amsterdam/oddball_example_small-fif.gz) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fname)
# Isotrak not found
#     Range : 2903 ... 112000 =     29.030 ...  1120.000 secs
# Ready.

# %%
raw
# raw.resample
# raw.filter
# raw.drop_channels
# Out:
# <Raw | oddball_example_small-fif.gz, 64 x 109098 (1091.0 s), ~68 kB, data not loaded>

# %%
dir(raw)

# %%
raw.crop?
raw.filter?

# %%
raw.filter(1,20)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 331 samples (3.310 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# ...

# %%
raw = mne.io.read_raw_fif(fname, preload=True)
# Out:
# Opening raw data file mne_workshop_amsterdam/oddball_example_small-fif.gz...
# <ipython-input-80-7341ee706cdd>:1: RuntimeWarning: This filename (mne_workshop_amsterdam/oddball_example_small-fif.gz) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fname, preload=True)
# Isotrak not found
#     Range : 2903 ... 112000 =     29.030 ...  1120.000 secs
# Ready.
# Reading 0 ... 109097  =      0.000 ...  1090.970 secs...

# %%
raw.filter(1,20)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 331 samples (3.310 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# ...

# %%
raw.plot();
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py:263: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   c = np.array(c)
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
ica = mne.preprocessing.ICA(n_components=20, random_state=0)

# %%
ica.fit(raw.copy().filter(8, 35))
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 165 samples (1.650 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# ...

# %%
ica.plot_components(outlines="skirt");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-9432743d9f06> in <module>
# ----> 1 ica.plot_components(outlines="skirt");
#
# /usr/local/lib/python3.8/dist-packages/mne/preprocessing/ica.py in plot_components(self, picks, ch_type, inst, plot_std, reject, sensors, show_names, contours, outlines, sphere, image_interp, extrapolate, border, res, size, cmap, vlim, vmin, vmax, cnorm, colorbar, cbar_fmt, axes, title, nrows, ncols, show, topomap_args, image_args, psd_args, verbose)
#    2192             title=None, nrows='auto', ncols='auto', show=True,
#    2193             topomap_args=None, image_args=None, psd_args=None, verbose=None):
# -> 2194         return plot_ica_components(
#    2195             self, picks=picks, ch_type=ch_type, inst=inst, plot_std=plot_std,
#    2196             reject=reject, sensors=sensors, show_names=show_names,
#
# ...

# %%
ica.exclude = [1, 10, 14, 17, 18, 19]

# %%
bad_idx, scores = ica.find_bads_eog(raw, 'SO2', threshold=2)
print(bad_idx)
# Out:
# Using EOG channel: SO2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1000 samples (10.000 sec)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# ...

# %%
raw.plot();
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py:263: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   c = np.array(c)
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
ica.apply(raw.copy(), exclude=ica.exclude).plot();
# Out:
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 6 ICA components
#     Projecting back using 63 PCA components
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py:263: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   c = np.array(c)
# <MNEBrowseFigure size 576x576 with 4 Axes>
